# %%
import pandas as pd

# %%
origen = 'enviados-const_merged_0-2025-08-29T09-23.csv'
df = pd.read_csv(origen)
df.head()
# Out:
#                                               nombre  \
# 0  Vidrios Millicay (vidriería y aberturas de alu...
# 1                                 Metalurgica Tobías
# 2                          La Banderola® – Aberturas
# 3                      Vidrios y Aberturas don Bosco
# 4                                     Alce Aberturas
#
#                                    dir         tlf  enviado
# 0                       1546 Félix Paz  3514666826    False
# 1  2626 Avenida Monseñor Pablo Cabrera  3516770759     True
# 2                                    ·  3516347939     True
# 3                   Av. Don Bosco 5011  3515575052     True
# 4                       Av. Colón 3879  3513936028     True

# %%
sin_wp = df[df['enviado'] == False]
con_wp = df[df['enviado'] == True]

# %%
print(sin_wp.shape, con_wp.shape)
# Out:
# (42, 4) (43, 4)

# %%
df[(df['tlf'] == 3516770759)]
# Out:
#                nombre                                  dir         tlf  \
# 1  Metalurgica Tobías  2626 Avenida Monseñor Pablo Cabrera  3516770759
#
#    enviado
# 1     True
